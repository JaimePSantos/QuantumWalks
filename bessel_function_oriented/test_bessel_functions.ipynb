# %%
import numpy as np
import scipy.special as sp
import matplotlib.pyplot as plt

# %%
plt.matplotlib.rc('text', use)

# %%
xi = 0
xf = 15
nx = 500

x = np.linspace(xi, xf, nx)

# %%
nb = 6

for v in range(0,nb):
    plt.plot(x, sp.jv(v,x), label='$J_{x}(x)$'.format(x=v))
    
plt.legend()
plt.show()

# %%
"My name is {fname}, I'm {age}".format(fname = "John", age = 36)
